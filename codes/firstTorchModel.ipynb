# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
import timm

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from os import path

print("Hello")
# Out:
# Hello

# %%
class PlayingCardDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data = ImageFolder(data_dir, transform=transform)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        return self.data[index]
    
    @property
    def classess(self):
        return self.data.classes

# %%
the_dataSets_path = "/home/rajeet/pyTorchModelForImageDetection/cardsDataset/train"
print(path.exists(the_dataSets_path))


dataset = PlayingCardDataset(
    data_dir= the_dataSets_path
)
# Out:
# True

# %%
len(dataset)
# Out:
# 7624

# %%
image, label = dataset[5000]

image
print(label)
# Out:
# 34

# %%
# Getting a dictionary associating target values(class name to index) with folder names
target_to_class = {classesIndex: folderName for classesIndex, folderName in ImageFolder(the_dataSets_path).class_to_idx.items()}

print(target_to_class)
# Out:
# {'ace of clubs': 0, 'ace of diamonds': 1, 'ace of hearts': 2, 'ace of spades': 3, 'eight of clubs': 4, 'eight of diamonds': 5, 'eight of hearts': 6, 'eight of spades': 7, 'five of clubs': 8, 'five of diamonds': 9, 'five of hearts': 10, 'five of spades': 11, 'four of clubs': 12, 'four of diamonds': 13, 'four of hearts': 14, 'four of spades': 15, 'jack of clubs': 16, 'jack of diamonds': 17, 'jack of hearts': 18, 'jack of spades': 19, 'joker': 20, 'king of clubs': 21, 'king of diamonds': 22, 'king of hearts': 23, 'king of spades': 24, 'nine of clubs': 25, 'nine of diamonds': 26, 'nine of hearts': 27, 'nine of spades': 28, 'queen of clubs': 29, 'queen of diamonds': 30, 'queen of hearts': 31, 'queen of spades': 32, 'seven of clubs': 33, 'seven of diamonds': 34, 'seven of hearts': 35, 'seven of spades': 36, 'six of clubs': 37, 'six of diamonds': 38, 'six of hearts': 39, 'six of spades': 40, 'ten of clubs': 41, 'ten of diamonds': 42, 'ten of hearts': 43, 'ten of spades': 44, 'three of clubs
# ...

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor()
])

# %%
tesored_The_Dataset = PlayingCardDataset(data_dir=the_dataSets_path, transform=transform)

# %%
tesored_The_Dataset[100]
# Out:
# (tensor([[[0.0000, 0.0039, 0.0078,  ..., 0.0039, 0.0039, 0.0039],
#           [0.0039, 0.0078, 0.0431,  ..., 0.0196, 0.0039, 0.0078],
#           [0.0235, 0.0392, 0.3490,  ..., 0.2392, 0.0314, 0.0118],
#           ...,
#           [0.0039, 0.0235, 0.2392,  ..., 0.2196, 0.0314, 0.0118],
#           [0.0039, 0.0039, 0.0235,  ..., 0.0118, 0.0078, 0.0039],
#           [0.0039, 0.0078, 0.0039,  ..., 0.0039, 0.0039, 0.0039]],
#
#          [[0.0078, 0.0078, 0.0039,  ..., 0.0039, 0.0039, 0.0039],
#           [0.0039, 0.0039, 0.0392,  ..., 0.0196, 0.0039, 0.0078],
#           [0.0078, 0.0275, 0.3373,  ..., 0.2392, 0.0275, 0.0078],
#           ...,
#           [0.0039, 0.0235, 0.2431,  ..., 0.2196, 0.0314, 0.0078],
#           [0.0039, 0.0039, 0.0235,  ..., 0.0157, 0.0078, 0.0039],
#           [0.0039, 0.0078, 0.0039,  ..., 0.0078, 0.0078, 0.0039]],
#
#          [[0.0196, 0.0196, 0.0118,  ..., 0.0118, 0.0118, 0.0118],
#           [0.0118, 0.0078, 0.0353,  ..., 0.0157, 0.0039, 0.0078],
# ...

# %%
image, label = anotherDataset[100]

print(label)
print(image.shape)
# Out:
# 0
# torch.Size([3, 128, 128])

# %%
dataloader = DataLoader(tesored_The_Dataset, batch_size= 32, shuffle=True)

# %%
for images, labels in dataloader:
    break

# %%
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([32, 3, 128, 128])
# torch.Size([32])

# %%
labels
# Out:
# tensor([19, 18, 29, 42, 16, 19, 40, 36,  3, 27, 34,  8, 17, 10,  4, 19, 42, 48,
#         48, 46, 19, 33, 23, 15, 14, 46, 48,  8, 23, 20, 48, 47])

# %%
class SImpleCardClassifier(nn.Module):
    def __init__(self, num_casss=53):
        self.base_odel = timm.create_model('efficientnet_b0', pretrained=True)
        enet_out_ze = 1280

    def forward(self, x):
        return output
